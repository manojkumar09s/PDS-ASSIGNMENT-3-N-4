# %%
from requests.api import head
import requests
import pandas as pd

# %%
#city_name = input("Enter city name: ")
url = "http://api.coincap.io/v2/assets"

headers = { 'Content-Type': 'application/json', 'accept-encoding':'deflate'}

# %%
response = requests.request("GET",url,headers=headers,data={})

# %%
res = requests.get(url)
print(res)
# Out:
# <Response [200]>

# %%
responseData = response.json()
print(responseData)
# Out:
# {'data': [{'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC', 'name': 'Bitcoin', 'supply': '19684812.0000000000000000', 'maxSupply': '21000000.0000000000000000', 'marketCapUsd': '1260400728541.9757553559301928', 'volumeUsd24Hr': '12488725992.9463575533966404', 'priceUsd': '64029.0965716094090894', 'changePercent24Hr': '0.9807121628146753', 'vwap24Hr': '63018.3169779604107659', 'explorer': 'https://blockchain.info/'}, {'id': 'ethereum', 'rank': '2', 'symbol': 'ETH', 'name': 'Ethereum', 'supply': '120071733.9252206000000000', 'maxSupply': None, 'marketCapUsd': '371391276572.3479221061211171', 'volumeUsd24Hr': '6799756201.6445022894406831', 'priceUsd': '3093.0783160310357701', 'changePercent24Hr': '-0.0676691744387559', 'vwap24Hr': '3067.6212607792968859', 'explorer': 'https://etherscan.io/'}, {'id': 'tether', 'rank': '3', 'symbol': 'USDT', 'name': 'Tether', 'supply': '108732462510.7544700000000000', 'maxSupply': None, 'marketCapUsd': '108839303631.6670551840117292', 'volumeUsd24Hr': '25203
# ...

# %%
df = pd.json_normalize(responseData, 'data')

# %%
print(df)
# Out:
#               id rank symbol         name                         supply  \
# 0        bitcoin    1    BTC      Bitcoin      19684812.0000000000000000
# 1       ethereum    2    ETH     Ethereum     120071733.9252206000000000
# 2         tether    3   USDT       Tether  108732462510.7544700000000000
# 3   binance-coin    4    BNB          BNB     166801148.0000000000000000
# 4         solana    5    SOL       Solana     446733698.7496363500000000
# ..           ...  ...    ...          ...                            ...
# 95          celo   96   CELO         Celo     533817831.0000000000000000
# 96           nxm   97    NXM          NXM       6594067.8412913900000000
# 97   rocket-pool   98    RPL  Rocket Pool      20292984.9475469900000000
# 98     ravencoin   99    RVN    Ravencoin   13740509327.1639180000000000
# 99          qtum  100   QTUM         Qtum     104755842.0000000000000000
#
#                        maxSupply                    marketCapUsd  \
# ...

# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv('/content/drive/MyDrive/PDS ASSIGNMENT-2/extract_data.csv', index=False)

# %%
df_checker = pd.read_csv('/content/drive/MyDrive/PDS ASSIGNMENT-2/extract_data.csv')
print(df_checker)
# Out:
#               id  rank symbol         name        supply     maxSupply  \
# 0        bitcoin     1    BTC      Bitcoin  1.968481e+07  2.100000e+07
# 1       ethereum     2    ETH     Ethereum  1.200717e+08           NaN
# 2         tether     3   USDT       Tether  1.087325e+11           NaN
# 3   binance-coin     4    BNB          BNB  1.668011e+08  1.668011e+08
# 4         solana     5    SOL       Solana  4.467337e+08           NaN
# ..           ...   ...    ...          ...           ...           ...
# 95          celo    96   CELO         Celo  5.338178e+08  1.000000e+09
# 96           nxm    97    NXM          NXM  6.594068e+06           NaN
# 97   rocket-pool    98    RPL  Rocket Pool  2.029298e+07           NaN
# 98     ravencoin    99    RVN    Ravencoin  1.374051e+10  2.100000e+10
# 99          qtum   100   QTUM         Qtum  1.047558e+08  1.078224e+08
#
#     marketCapUsd  volumeUsd24Hr      priceUsd  changePercent24Hr  \
# ...

# %%
df.head()
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19684812.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120071733.9252206000000000
# 2        tether    3   USDT    Tether  108732462510.7544700000000000
# 3  binance-coin    4    BNB       BNB     166801148.0000000000000000
# 4        solana    5    SOL    Solana     446733698.7496363500000000
#
#                     maxSupply                    marketCapUsd  \
# 0   21000000.0000000000000000  1260400728541.9757553559301928
# 1                        None   371391276572.3479221061211171
# 2                        None   108839303631.6670551840117292
# 3  166801148.0000000000000000    90116950906.4538692701777972
# 4                        None    61239896478.1208594601801917
#
#                   volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0  12488725992.9463575533966404  64029.0965716094090894   0.9807121628146753
# ...

# %%
df
# Out:
#               id rank symbol         name                         supply  \
# 0        bitcoin    1    BTC      Bitcoin      19684812.0000000000000000
# 1       ethereum    2    ETH     Ethereum     120071733.9252206000000000
# 2         tether    3   USDT       Tether  108732462510.7544700000000000
# 3   binance-coin    4    BNB          BNB     166801148.0000000000000000
# 4         solana    5    SOL       Solana     446733698.7496363500000000
# ..           ...  ...    ...          ...                            ...
# 95          celo   96   CELO         Celo     533817831.0000000000000000
# 96           nxm   97    NXM          NXM       6594067.8412913900000000
# 97   rocket-pool   98    RPL  Rocket Pool      20292984.9475469900000000
# 98     ravencoin   99    RVN    Ravencoin   13740509327.1639180000000000
# 99          qtum  100   QTUM         Qtum     104755842.0000000000000000
#
#                        maxSupply                    marketCapUsd  \
# ...

# %% [markdown]
# Hence, Finally we can clearly see that the data is extracted from online third party API, and we are extracting the data from the json format. Atlast, we are going to export into the csv file as shown below.
